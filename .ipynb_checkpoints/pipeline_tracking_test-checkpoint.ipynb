# %%
# preprocessing step 1: convert the h264 to mp4

import glob
import os
import subprocess

videos = "../videos/videos_mp4"

if not os.path.exists("videos/videos_mp4"):
    os.mkdir("videos/videos_mp4")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0d80c8bf3e1e> in <module>()
#       8
#       9 if not os.path.exists("videos/videos_mp4"):
# ---> 10     os.mkdir("videos/videos_mp4")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'videos/videos_mp4'

# %%
for video in glob.glob(os.path.join('videos', '*.h264')):  
    path = os.path.split(video)   
    video_mp4 = os.path.join(path[0],"videos_mp4",os.path.splitext(path[1])[0] + '.mp4')

    subprocess.call(['ffmpeg', '-framerate', '2', '-fflags', '+genpts', '-i', video, '-c', 'copy', video_mp4])
    break

# %%
# %env KERAS_BACKEND=theano
# %env THEANO_FLAGS=floatX=float32,device=cpu
# Out:
# env: KERAS_BACKEND=theano
# env: THEANO_FLAGS=floatX=float32,device=cpu

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport bb_behavior
# %aimport bb_behavior.plot
# %aimport bb_behavior.tracking
# %aimport bb_behavior.tracking.pipeline

import bb_behavior
import bb_behavior.plot
import bb_behavior.tracking
import bb_behavior.tracking.pipeline
# Out:
# Using Theano backend.

# %%
configs = [
        dict(path="videos/videos_mp4/e00_2018-09-09-00-00-11.mp4",
             tag_pixel_diameter=15,
             n_frames=100,
             confidence_filter_detections=0.0,
             confidence_filter_tracks=0.0,
             coordinate_scale=1.0,
            start_time=None,
            fps=2.0,
            cam_id=0)
]
configs = [
        dict(path="/home/david/Downloads/30.10_00002.avi",
             tag_pixel_diameter=29,
             n_frames=None,
             confidence_filter_detections=0.0,
             confidence_filter_tracks=0.0,
             coordinate_scale=1.0,
            start_time=None,
            fps=25.0,
            cam_id=0)
]
configs = [
        dict(path="/home/david/Downloads/20181122_00004_hevc.mp4",
             tag_pixel_diameter=24,
             n_frames=None,
             confidence_filter_detections=0.0,
             confidence_filter_tracks=0.0,
             coordinate_scale=1.0,
            start_time=None,
            fps=3.0,
            cam_id=0)
]
configs = [
        dict(path="/home/david/Downloads/ants/20181129_1.mp4",
             tag_pixel_diameter=30,
             n_frames=None,
             confidence_filter_detections=0.0,
             confidence_filter_tracks=0.0,
             coordinate_scale=1.0,
            start_time=None,
            fps=4.0,
            cam_id=0)
]
config=configs[0]

# %% [markdown]
# ## Run

# %%
default_pipeline = None

# %%
from bb_behavior.tracking.pipeline import get_default_pipeline
default_pipeline = get_default_pipeline(localizer_threshold="0.65")
# Out:
# Exception ignored in: <bound method VideoReader.__del__ of <pipeline.io.VideoReader object at 0x7f81c3c62470>>
# Traceback (most recent call last):
#   File "/home/tscho/.local/lib/python3.6/site-packages/pipeline/io.py", line 71, in __del__
#     self.video_pipe.kill()
# AttributeError: 'VideoReader' object has no attribute 'video_pipe'
# /home/tscho/.local/lib/python3.6/site-packages/keras/backend/theano_backend.py:1032: UserWarning: DEPRECATION: the 'ds' parameter is not going to exist anymore as it is going to be replaced by the parameter 'ws'.
#   mode='max')
# /home/tscho/.local/lib/python3.6/site-packages/keras/backend/theano_backend.py:1032: UserWarning: DEPRECATION: the 'st' parameter is not going to exist anymore as it is going to be replaced by the parameter 'stride'.
#   mode='max')
# /home/tscho/.local/lib/python3.6/site-packages/keras/backend/theano_backend.py:1032: UserWarning: DEPRECATION: the 'padding' parameter is not going to exist anymore as it is going to be replaced by the parameter 'pad'.
#   mode='max')

# %%
from tqdm import tqdm_notebook # progress bar

import math
import numpy as np
from bb_tracking.data.constants import DETKEY
#from bb_tracking.tracking import score_id_sim_v
from bb_tracking.tracking import distance_orientations_v, distance_positions_v

from bb_behavior.tracking.pipeline import detect_markers_in_video
from bb_behavior.tracking.pipeline import track_detections_dataframe
from bb_behavior.tracking.pipeline import display_tracking_results
tqdm_notebook
# Out:
# <function tqdm.tqdm_notebook>

# %%
num_processed_videos = 0
video_data = dict()
frame_info = None
detections = None


for config in tqdm_notebook(configs):
    start_time, path = config["start_time"], config["path"]
    cam_id = config["cam_id"]#int(path[cam_id_idx])
    #pipelines.reset(4)
    
    try:
        num_processed_videos += 1

        frame_info, detections = detect_markers_in_video(path,
                                                      pipeline=default_pipeline,#pipeline=pipelines(),
                                                     tag_pixel_diameter=config["tag_pixel_diameter"],
                                                      n_frames=config["n_frames"],
                                                      fps=config["fps"],
                                                     progress="tqdm_notebook"
                                                             )
        tracks = track_detections_dataframe(detections,
                                            tracker="/buffer/ag_ki/tracking/tracker.det_score_fun.frag_score_fun.dill",
                                            confidence_filter_detections=config["confidence_filter_detections"],
                                           confidence_filter_tracks=config["confidence_filter_tracks"],
                                            coordinate_scale=config["coordinate_scale"]
                                           )
        
        
        video_data[path] = (frame_info, detections, tracks)
    
    except Exception as err:
        print(err)
        raise
    # only first vid
    break
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# not enough values to unpack (expected 2, got 0)
# --------------------------------------------------------------------------
# ValueError                               Traceback (most recent call last)
# <ipython-input-50-75011bd27dfa> in <module>()
#      18                                                       n_frames=config["n_frames"],
#      19                                                       fps=config["fps"],
# ---> 20                                                      progress="tqdm_notebook"
#      21                                                              )
#      22         tracks = track_detections_dataframe(detections,
#
# ~/.local/lib/python3.6/site-packages/bb_behavior/tracking/pipeline.py in detect_markers_in_video(source_path, source_type, pipeline, pipeline_factory, tag_pixel_diameter, timestamps, start_timestamp, fps, cam_id, verbose, n_frames, progress, calculate_confidences, confidence_filter, use_parallel_jobs)
#     317     video_dataframe = []
#     318     try:
# --> 319         jobs()
#     320     except KeyboardInterrupt:
#     321         interrupted = True
#
# ~/.local/lib/python3.6/site-packages/bb_behavior/tracking/pipeline.py in sequential_jobs()
#     308     else:
#     309         def sequential_jobs():
# --> 310             for im in source():
#     311                 if im is not None:
#     312                     detections = get_detections_from_frame(*im)
#
# ~/.local/lib/python3.6/site-packages/bb_behavior/tracking/pipeline.py in get_frames_from_video()
#     207
#     208     def get_frames_from_video():
# --> 209         frames_generator = bb_pipeline.io.raw_frames_generator(source_path, format=None)
#     210
#     211         for idx, (im, ts) in enumerate(zip(interruptable_frame_generator(frames_generator), timestamps)):
#
# ~/.local/lib/python3.6/site-packages/pipeline/io.py in raw_frames_generator(path_video, format, stderr_fd)
#      88 def raw_frames_generator(path_video, format='guess_on_ext', stderr_fd=None):
#      89     "yields the frames of the video."
# ---> 90     return VideoReader(path_video, stderr_fd, format=format)
#      91
#      92
#
# ~/.local/lib/python3.6/site-packages/pipeline/io.py in __init__(self, video_path, ffmpeg_stderr_fd, format, ffmpeg_bin, ffprobe_bin)
#      44         pipe = sp.Popen(resolution_command, stdout=sp.PIPE, stderr=sp.PIPE)
#      45         infos = pipe.stdout.readlines()
# ---> 46         self.w, self.h = [int(s.decode('utf-8').strip().split('=')[1]) for s in infos]
#      47
#      48         self.video_pipe = sp.Popen(vidread_command,
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %% [raw]
# tracks = track_detections_dataframe(detections,
#                                             tracker="/buffer/ag_ki/tracking/tracker.det_score_fun.frag_score_fun.dill",
#                                             confidence_filter_detections=config["confidence_filter_detections"],
#                                            confidence_filter_tracks=config["confidence_filter_tracks"],
#                                             coordinate_scale=config["coordinate_scale"]
#                                            )
#
#
# video_data[path] = (frame_info, detections, tracks)

# %%
tracks = track_detections_dataframe(detections,
            tracker="/buffer/ag_ki/tracking/tracker.det_score_fun.frag_score_fun.dill",
            confidence_filter_detections=0.25,
           confidence_filter_tracks=0.2,#0.001,
            coordinate_scale=2.0,
            use_weights_for_tracked_id=True
           )
#tracks.bee_id = tracks.bee_id.astype(int)
display_tracking_results(config["path"], frame_info, detections, tracks)
# Out:
# Found 34099 detections belonging to 423 unique tracks and 76 individuals.
# Detection/track statistics:
# Individual statistics:
# Individual 764 in track 70.0 has only 1 detection(s). Skipping.
# Individual 995 in track 520.0 has only 1 detection(s). Skipping.
# Individual 1534 in track 230.0 has only 2 detection(s). Skipping.
# Individual 1932 in track 559.0 has only 1 detection(s). Skipping.
# Individual 1983 in track 494.0 has only 1 detection(s). Skipping.
# Individual 1986 in track 127.0 has only 2 detection(s). Skipping.
# Individual 1992 in track 119.0 has only 3 detection(s). Skipping.
# Individual 1994 in track 110.0 has only 1 detection(s). Skipping.
# Individual 1995 in track 213.0 has only 1 detection(s). Skipping.
# Individual 1998 in track 209.0 has only 1 detection(s). Skipping.
# Individual 2000 in track 109.0 has only 2 detection(s). Skipping.
# Individual 2012 in track 178.0 has only 1 detection(s). Skipping.
# Individual 2021 in track 404.0 has only 3 detection(s). Skipping.
# Individual 2028 in track 208.0 has only 2 detection(s). Skipping.
# Individual 2038 in track 523.0 has only 2 detection(s). Skipping.
# Individual 2040 in track 36.0 has only 1 detection(s). Skipping.
# Individual 2041 in track 573.0 has only 2 detection(s). Skipping.
# Individual 2977 in track 502.0 has only 1 detection(s). Skipping.
# Individual 3582 in track 154.0 has only 1 detection(s). Skipping.
# Individual 3875 in track 225.0 has only 1 detection(s). Skipping.
# Individual 3937 in track 218.0 has only 1 detection(s). Skipping.
# Individual 3967 in track 532.0 has only 1 detection(s). Skipping.
# Individual 3971 in track 196.0 has only 1 detection(s). Skipping.
# Individual 3973 in track 557.0 has only 1 detection(s). Skipping.
# Individual 4008 in track 393.0 has only 2 detection(s). Skipping.
# Individual 4016 in track 59.0 has only 1 detection(s). Skipping.
# Individual 4028 in track 389.0 has only 2 detection(s). Skipping.
# Individual 4041 in track 113.0 has only 1 detection(s). Skipping.
# Individual 4043 in track 114.0 has only 2 detection(s). Skipping.
# Individual 4065 in track 553.0 has only 1 detection(s). Skipping.
# Individual 4067 in track 287.0 has only 1 detection(s). Skipping.
# Individual 4070 in track 269.0 has only 2 detection(s). Skipping.
# Individual 4076 in track 144.0 has only 3 detection(s). Skipping.
# Individual 4078 in track 312.0 has only 1 detection(s). Skipping.
# Individual 4080 in track 60.0 has only 1 detection(s). Skipping.
# Individual 4094 in track 385.0 has only 1 detection(s). Skipping.

# %%
import bb_utils

# %%
def to_bee_id(bits):
    return bb_utils.ids.BeesbookID.from_bb_binary(bits).as_ferwar()
bee_ids = list(map(to_bee_id, detections.beeID.values))
detections["bee_id"] = bee_ids

# %%
with open("/home/david/Downloads/ants/detections.csv", "w") as f:
    detections.to_csv(f)
with open("/home/david/Downloads/ants/tracks.csv", "w") as f:
    tracks.to_csv(f)

# %%
# debugging pipeline io.py

video_path = "videos/videos_mp4/e00_2018-09-09-00-00-11.mp4"
ffmpeg_stderr_fd=None
format='guess_on_ext'
ffmpeg_bin='ffmpeg'
ffprobe_bin='ffprobe'

def guess_format_on_extension(video_path):
    _, ext = os.path.splitext(video_path)
    if ext == '.mkv':
        format = None
    elif ext == '.avi':
        format = 'hevc'
    else:
        raise Exception("Unknown extension {}.".format(ext))
    return format

if format == 'guess_on_ext':
    format = guess_format_on_extension(video_path)

vidread_command = [
    ffmpeg_bin,
    '-i', video_path,
    '-f', 'image2pipe',
    '-pix_fmt', 'gray',
    '-vsync', '0',
    '-vcodec', 'rawvideo', '-'
]

if format is not None:
    vidread_command.insert(1, '-vcodec')
    vidread_command.insert(2, format)

resolution_command = [
    ffprobe_bin,
    '-v', 'error',
    '-of', 'flat=s=_',
    '-select_streams', 'v:0',
    '-show_entries', 'stream=height,width',
    video_path
]

pipe = sp.Popen(resolution_command, stdout=sp.PIPE, stderr=sp.PIPE)
infos = pipe.stdout.readlines()
self.w, self.h = [int(s.decode('utf-8').strip().split('=')[1]) for s in infos]

self.video_pipe = sp.Popen(vidread_command,
                           stdout=sp.PIPE,
                           stderr=ffmpeg_stderr_fd)
self.frames = 0
